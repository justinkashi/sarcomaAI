# %%
#STEP 1 - VIRCHOW2 ON WSI

#DEPENDENCIES
#pip install torch torchvision
#pip install timm
#pip install huggingface_hub
#pip install openslide-python       # WSI reading (brew install openslide first on mac)
#pip install openslide-bin
#pip install Pillow
#pip install h5py                   # saving tile embeddings
#pip install scikit-image           # Otsu thresholding for tissue segmentation
#pip install numpy
#pip install ipywidgets #to use hf login() in notebook

# %%
import os
import glob
import timm
import torch
import numpy as np
import h5py
import openslide 
from PIL import Image
from huggingface_hub import login
from timm.data import resolve_data_config
from timm.data.transforms_factory import create_transform
from timm.layers import SwiGLUPacked
#from skimage.filters import threshold_otsu
#from skimage.color import rgb2hsv

HF_TOKEN = os.environ.get("HF_TOKEN")  # export HF_TOKEN=hf_xxx before running

DEVICE = "mps" if torch.backends.mps.is_available() else "cpu"
login(token=HF_TOKEN)
print("logged in")
model = timm.create_model(
    "hf-hub:paige-ai/Virchow2",
    pretrained=True,
    mlp_layer=SwiGLUPacked,
    act_layer=torch.nn.SiLU,
)

model = model.eval().to(DEVICE)

transforms = create_transform(**resolve_data_config(model.pretrained_cfg, model=model))
print("virchow2 loaded")
# Out:
# logged in
# model.safetensors:   0%|          | 0.00/2.53G [00:00<?, ?B/s]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/sarcomaAI/mmnn2/lib/python3.12/site-packages/huggingface_hub/file_download.py:549, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, tqdm_class, _tqdm_bar)
#     547     progress.update(progress_bytes)
# --> 549 download_files(
#     550     xet_download_info,
#     551     endpoint=connection_info.endpoint,
#     552     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     553     token_refresher=token_refresher,
#     554     progress_updater=[progress_updater],
#     555     request_headers=xet_headers,
#     556 )
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 21
#      17
#      18 DEVICE = "mps" if torch.backends.mps.is_available() else "cpu"
#      19 login(token=HF_TOKEN)
#      20 print("logged in")
# ---> 21 model = timm.create_model(
#      22     "hf-hub:paige-ai/Virchow2",
#      23     pretrained=True,
#      24     mlp_layer=SwiGLUPacked,
#
# File ~/sarcomaAI/mmnn2/lib/python3.12/site-packages/timm/models/_factory.py:138, in create_model(model_name, pretrained, pretrained_cfg, pretrained_cfg_overlay, checkpoint_path, cache_dir, scriptable, exportable, no_jit, **kwargs)
#     136 create_fn = model_entrypoint(model_name)
#     137 with set_layer_config(scriptable=scriptable, exportable=exportable, no_jit=no_jit):
# --> 138     model = create_fn(
#     139         pretrained=pretrained,
#     140         pretrained_cfg=pretrained_cfg,
#     141         pretrained_cfg_overlay=pretrained_cfg_overlay,
#     142         cache_dir=cache_dir,
#     143         **kwargs,
#     144     )
#     146 if checkpoint_path:
#     147     load_checkpoint(model, checkpoint_path)
#
# File ~/sarcomaAI/mmnn2/lib/python3.12/site-packages/timm/models/vision_transformer.py:3242, in vit_huge_patch14_224(pretrained, **kwargs)
#    3239 """ ViT-Huge model (ViT-H/14) from original paper (https://arxiv.org/abs/2010.11929).
#    3240 """
#    3241 model_args = dict(patch_size=14, embed_dim=1280, depth=32, num_heads=16)
# -> 3242 model = _create_vision_transformer('vit_huge_patch14_224', pretrained=pretrained, **dict(model_args, **kwargs))
#    3243 return model
#
# File ~/sarcomaAI/mmnn2/lib/python3.12/site-packages/timm/models/vision_transformer.py:3065, in _create_vision_transformer(variant, pretrained, use_naflex, **kwargs)
#    3062 if 'siglip' in variant and kwargs.get('global_pool', None) != 'map':
#    3063     strict = False
# -> 3065 return build_model_with_cfg(
#    3066     VisionTransformer,
#    3067     variant,
#    3068     pretrained,
#    3069     pretrained_filter_fn=_filter_fn,
#    3070     pretrained_strict=strict,
#    3071     feature_cfg=dict(out_indices=out_indices, feature_cls='getter'),
#    3072     **kwargs,
#    3073 )
#
# File ~/sarcomaAI/mmnn2/lib/python3.12/site-packages/timm/models/_builder.py:457, in build_model_with_cfg(model_cls, variant, pretrained, pretrained_cfg, pretrained_cfg_overlay, model_cfg, feature_cfg, pretrained_strict, pretrained_filter_fn, cache_dir, kwargs_filter, **kwargs)
#     455 num_classes_pretrained = 0 if features else getattr(model, 'num_classes', kwargs.get('num_classes', 1000))
#     456 if pretrained:
# --> 457     load_pretrained(
#     458         model,
#     459         pretrained_cfg=pretrained_cfg,
#     460         num_classes=num_classes_pretrained,
#     461         in_chans=kwargs.get('in_chans', 3),
#     462         filter_fn=pretrained_filter_fn,
#     463         strict=pretrained_strict,
#     464         cache_dir=cache_dir,
#     465     )
#     467 # Wrap the model in a feature extraction module if enabled
#     468 if features:
#
# File ~/sarcomaAI/mmnn2/lib/python3.12/site-packages/timm/models/_builder.py:226, in load_pretrained(model, pretrained_cfg, num_classes, in_chans, filter_fn, strict, cache_dir)
#     224             state_dict = load_state_dict_from_hf(*pretrained_loc, cache_dir=cache_dir)
#     225     else:
# --> 226         state_dict = load_state_dict_from_hf(pretrained_loc, weights_only=True, cache_dir=cache_dir)
#     227 elif load_from == 'local-dir':
#     228     _logger.info(f'Loading pretrained weights from local directory ({pretrained_loc})')
#
# File ~/sarcomaAI/mmnn2/lib/python3.12/site-packages/timm/models/_hub.py:227, in load_state_dict_from_hf(model_id, filename, weights_only, cache_dir)
#     225 for safe_filename in _get_safe_alternatives(filename):
#     226     try:
# --> 227         cached_safe_file = hf_hub_download(
#     228             repo_id=hf_model_id,
#     229             filename=safe_filename,
#     230             revision=hf_revision,
#     231             cache_dir=cache_dir,
#     232         )
#     233         _logger.info(
#     234             f"[{model_id}] Safe alternative available for '{filename}' "
#     235             f"(as '{safe_filename}'). Loading weights using safetensors.")
#     236         return safetensors.torch.load_file(cached_safe_file, device="cpu")
#
# File ~/sarcomaAI/mmnn2/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File ~/sarcomaAI/mmnn2/lib/python3.12/site-packages/huggingface_hub/file_download.py:986, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     965     return _hf_hub_download_to_local_dir(
#     966         # Destination
#     967         local_dir=local_dir,
#    (...)    983         dry_run=dry_run,
#     984     )
#     985 else:
# --> 986     return _hf_hub_download_to_cache_dir(
#     987         # Destination
#     988         cache_dir=cache_dir,
#     989         # File info
#     990         repo_id=repo_id,
#     991         filename=filename,
#     992         repo_type=repo_type,
#     993         revision=revision,
#     994         # HTTP info
#     995         endpoint=endpoint,
#     996         etag_timeout=etag_timeout,
#     997         headers=hf_headers,
#     998         token=token,
#     999         # Additional options
#    1000         local_files_only=local_files_only,
#    1001         force_download=force_download,
#    1002         tqdm_class=tqdm_class,
#    1003         dry_run=dry_run,
#    1004     )
#
# File ~/sarcomaAI/mmnn2/lib/python3.12/site-packages/huggingface_hub/file_download.py:1202, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1199 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1201 with WeakFileLock(lock_path):
# -> 1202     _download_to_tmp_and_move(
#    1203         incomplete_path=Path(blob_path + ".incomplete"),
#    1204         destination_path=Path(blob_path),
#    1205         url_to_download=url_to_download,
#    1206         headers=headers,
#    1207         expected_size=expected_size,
#    1208         filename=filename,
#    1209         force_download=force_download,
#    1210         etag=etag,
#    1211         xet_file_data=xet_file_data,
#    1212         tqdm_class=tqdm_class,
#    1213     )
#    1214     if not os.path.exists(pointer_path):
#    1215         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/sarcomaAI/mmnn2/lib/python3.12/site-packages/huggingface_hub/file_download.py:1826, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, headers, expected_size, filename, force_download, etag, xet_file_data, tqdm_class)
#    1824 if xet_file_data is not None and is_xet_available():
#    1825     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1826     xet_get(
#    1827         incomplete_path=incomplete_path,
#    1828         xet_file_data=xet_file_data,
#    1829         headers=headers,
#    1830         expected_size=expected_size,
#    1831         displayed_filename=filename,
#    1832         tqdm_class=tqdm_class,
#    1833     )
#    1834 else:
#    1835     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File ~/sarcomaAI/mmnn2/lib/python3.12/site-packages/huggingface_hub/file_download.py:544, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, tqdm_class, _tqdm_bar)
#     541 xet_headers = headers.copy()
#     542 xet_headers.pop("authorization", None)
# --> 544 with progress_cm as progress:
#     546     def progress_updater(progress_bytes: float):
#     547         progress.update(progress_bytes)
#
# File ~/sarcomaAI/mmnn2/lib/python3.12/site-packages/tqdm/std.py:1138, in tqdm.__exit__(self, exc_type, exc_value, traceback)
#    1135 def __enter__(self):
#    1136     return self
# -> 1138 def __exit__(self, exc_type, exc_value, traceback):
#    1139     try:
#    1140         self.close()
#
# KeyboardInterrupt:
